# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head(30000)
# Out:
#        Student ID       student_name gender grade            school_name  \
# 0               0       Paul Bradley      M   9th      Huang High School
# 1               1       Victor Smith      M  12th      Huang High School
# 2               2    Kevin Rodriguez      M  12th      Huang High School
# 3               3  Dr. Richard Scott      M  12th      Huang High School
# 4               4         Bonnie Ray      F   9th      Huang High School
# ...           ...                ...    ...   ...                    ...
# 29995       29995       Brett Garner      M   9th  Rodriguez High School
# 29996       29996   Jacqueline Clark      F  10th  Rodriguez High School
# 29997       29997      Justin Parker      M   9th  Rodriguez High School
# 29998       29998   Gloria Blackwell      F   9th  Rodriguez High School
# 29999       29999      Brandon Hayes      M  11th  Rodriguez High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
school_data_complete.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score', 'School ID', 'type', 'size', 'budget'],
#       dtype='object')

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
number_of_schools=school_data_complete["school_name"].nunique()
number_of_students = school_data_complete["student_name"].count()
total_budget = school_data["budget"].sum()
average_math_score = school_data_complete["math_score"].mean()
average_reading_score = school_data_complete["reading_score"].mean()




summary_dict = [{"Number of Schools":number_of_schools,
                 "Number of Students":number_of_students,
                 "Total Budget":total_budget,
                 "Average Math Score": average_math_score,
                 "Average Readiing Score": average_reading_score,
                
                }]

pd.DataFrame(summary_dict)
#top_30_math_score= school_data_complete.sort_values("math_score", ascending = False)
# Out:
#    Number of Schools  Number of Students  Total Budget  Average Math Score  \
# 0                 15               39170      24649428           78.985371
#
#    Average Readiing Score
# 0                81.87784

# %%
number_of_students = school_data_complete.groupby('school_name').count()['student_name']
number_of_students
# Out:
# school_name
# Bailey High School       4976
# Cabrera High School      1858
# Figueroa High School     2949
# Ford High School         2739
# Griffin High School      1468
# Hernandez High School    4635
# Holden High School        427
# Huang High School        2917
# Johnson High School      4761
# Pena High School          962
# Rodriguez High School    3999
# Shelton High School      1761
# Thomas High School       1635
# Wilson High School       2283
# Wright High School       1800
# Name: student_name, dtype: int64

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
b = school_data_complete.groupby('school_name').sum()['reading_score']
b1 = b/number_of_students
b1
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.848930
# Wilson High School       83.989488
# Wright High School       83.955000
# dtype: float64

# %%
c = school_data_complete.groupby('school_name').sum()['math_score']
c1 = c/number_of_students
c1
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.418349
# Wilson High School       83.274201
# Wright High School       83.682222
# dtype: float64

# %%
a = school_data_complete.groupby(['school_name']).first()


number_of_students = school_data_complete.groupby('school_name').count()['student_name']


total_budget = number_of_students * student_budget
total_budget

student_budget = a['budget'].mean()/a['size'].mean()
student_budget



a1 = school_data_complete.loc[school_data_complete['math_score'] >=70].groupby(['school_name']).size()
percenatge_passed_in_maths = a1/number_of_students*100

a2 = school_data_complete.loc[school_data_complete['reading_score'] >=70].groupby(['school_name']).size()
percenatge_passed_in_reading = a2/number_of_students*100

a3 = school_data_complete.loc[(school_data_complete['math_score'] >=70) & (school_data_complete['reading_score'] >=70)].groupby(['school_name']).size()
percenatge_passed_overall = a3/number_of_students*100

summary = pd.DataFrame({'School Type': a['type'],
                        'Total Students': number_of_students,
                        'Total Budget' : total_budget,

                       'Average Math Score' : c1,
                       'Average Reading Score' : b1,
                        '% Passing Math' : percenatge_passed_in_maths,
                        '% Passing Reading' : percenatge_passed_in_reading,
                        '% Overall Passing' : percenatge_passed_overall,

                       })

copy_of_summary = summary.copy()
copy_of_summary['Total Budget'] = copy_of_summary['Total Budget'].map("${:,.2f}".format)


copy_of_summary['Average Math Score'] = copy_of_summary['Average Math Score'].map("{:,.2f}".format)
copy_of_summary['Average Reading Score'] = copy_of_summary['Average Reading Score'].map("{:,.2f}".format)
copy_of_summary['% Passing Math'] = copy_of_summary['% Passing Math'].map("{:,.2f}%".format)
copy_of_summary['% Passing Reading'] = copy_of_summary['% Passing Reading'].map("{:,.2f}%".format)
copy_of_summary['% Overall Passing'] = copy_of_summary['% Overall Passing'].map("{:,.2f}%".format)

copy_of_summary
# Out:
#                       School Type  Total Students   Total Budget  \
# school_name
# Bailey High School       District            4976  $3,124,928.00
# Cabrera High School       Charter            1858  $1,081,356.00
# Figueroa High School     District            2949  $1,884,411.00
# Ford High School         District            2739  $1,763,916.00
# Griffin High School       Charter            1468    $917,500.00
# Hernandez High School    District            4635  $3,022,020.00
# Holden High School        Charter             427    $248,087.00
# Huang High School        District            2917  $1,910,635.00
# Johnson High School      District            4761  $3,094,650.00
# Pena High School          Charter             962    $585,858.00
# Rodriguez High School    District            3999  $2,547,363.00
# Shelton High School       Charter            1761  $1,056,600.00
# Thomas High School        Charter            1635  $1,043,130.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
copy_of_summary.sort_values('% Overall Passing', ascending = False).head(5)
# Out:
#                     School Type  Total Students   Total Budget  \
# school_name
# Cabrera High School     Charter            1858  $1,081,356.00
# Thomas High School      Charter            1635  $1,043,130.00
# Griffin High School     Charter            1468    $917,500.00
# Wilson High School      Charter            2283  $1,319,574.00
# Pena High School        Charter             962    $585,858.00
#
#                     Average Math Score Average Reading Score % Passing Math  \
# school_name
# Cabrera High School              83.06                 83.98         94.13%
# Thomas High School               83.42                 83.85         93.27%
# Griffin High School              83.35                 83.82         93.39%
# Wilson High School               83.27                 83.99         93.87%
# Pena High School                 83.84                 84.04         94.59%
#
#                     % Passing Reading % Overall Passing
# school_name
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
copy_of_summary.sort_values('% Overall Passing', ascending = True).head(5)
# Out:
#                       School Type  Total Students   Total Budget  \
# school_name
# Rodriguez High School    District            3999  $2,547,363.00
# Figueroa High School     District            2949  $1,884,411.00
# Huang High School        District            2917  $1,910,635.00
# Hernandez High School    District            4635  $3,022,020.00
# Johnson High School      District            4761  $3,094,650.00
#
#                       Average Math Score Average Reading Score % Passing Math  \
# school_name
# Rodriguez High School              76.84                 80.74         66.37%
# Figueroa High School               76.71                 81.16         65.99%
# Huang High School                  76.63                 81.18         65.68%
# Hernandez High School              77.29                 80.93         66.75%
# Johnson High School                77.07                 80.97         66.06%
#
#                       % Passing Reading % Overall Passing
# school_name
# ...

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
bins = [0, 584.99, 629.99, 644.99, 680]

group_names = ["0 - 585", "585-630", "630-645", "645-680"]

# %% [markdown]
# ## Reading Score by Grade

# %%
school_data_complete.groupby(['school_name', 'grade'])['math_score', 'reading_score'].mean().sort_values('grade')
# Out:
# C:\Users\nosha\AppData\Local\Temp/ipykernel_3500/2298377776.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   school_data_complete.groupby(['school_name', 'grade'])['math_score', 'reading_score'].mean().sort_values('grade')
#                              math_score  reading_score
# school_name           grade
# Bailey High School    10th    76.996772      80.907183
# Hernandez High School 10th    77.337408      80.660147
# Huang High School     10th    75.908735      81.512386
# Johnson High School   10th    76.691117      80.773431
# Griffin High School   10th    84.229064      83.706897
# Pena High School      10th    83.372000      83.612000
# Rodriguez High School 10th    76.612500      80.629808
# Ford High School      10th    77.672316      81.262712
# Shelton High School   10th    82.917411      83.441964
# Holden High School    10th    83.429825      83.324561
# ...

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
school_data_complete.groupby(['school_name', 'grade'])[ 'reading_score'].mean().unstack().reset_index()
# Out:
# grade            school_name       10th       11th       12th        9th
# 0         Bailey High School  80.907183  80.945643  80.912451  81.303155
# 1        Cabrera High School  84.253219  83.788382  84.287958  83.676136
# 2       Figueroa High School  81.408912  80.640339  81.384863  81.198598
# 3           Ford High School  81.262712  80.403642  80.662338  80.632653
# 4        Griffin High School  83.706897  84.288089  84.013699  83.369193
# 5      Hernandez High School  80.660147  81.396140  80.857143  80.866860
# 6         Holden High School  83.324561  83.815534  84.698795  83.677165
# 7          Huang High School  81.512386  81.417476  80.305983  81.290284
# 8        Johnson High School  80.773431  80.616027  81.227564  81.260714
# 9           Pena High School  83.612000  84.335938  84.591160  83.807273
# 10     Rodriguez High School  80.629808  80.864811  80.376426  80.993127
# 11       Shelton High School  83.441964  84.373786  82.781671  84.122642
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
summary = school_rankingdf.drop(['size_passing_maths', 'size_passing_reading', 'size_of_students_passed'],
                                         axis=1)
school_summarydf.head()
# Out:
#                      School Type  Total Students   Total Budget  \
# school_name
# Bailey High School      District            4976  $3,124,928.00
# Cabrera High School      Charter            1858  $1,081,356.00
# Figueroa High School    District            2949  $1,884,411.00
# Ford High School        District            2739  $1,763,916.00
# Griffin High School      Charter            1468    $917,500.00
#
#                      Average Math Score Average Reading Score % Passing Math  \
# school_name
# Bailey High School                77.05                 81.03         66.68%
# Cabrera High School               83.06                 83.98         94.13%
# Figueroa High School              76.71                 81.16         65.99%
# Ford High School                  77.10                 80.75         68.31%
# Griffin High School               83.35                 83.82         93.39%
#
#                      % Passing Reading % Overall Passing
# school_name
# ...

# %%
copy_of_summary
# Out:
#                       School Type  Total Students   Total Budget  \
# school_name
# Bailey High School       District            4976  $3,124,928.00
# Cabrera High School       Charter            1858  $1,081,356.00
# Figueroa High School     District            2949  $1,884,411.00
# Ford High School         District            2739  $1,763,916.00
# Griffin High School       Charter            1468    $917,500.00
# Hernandez High School    District            4635  $3,022,020.00
# Holden High School        Charter             427    $248,087.00
# Huang High School        District            2917  $1,910,635.00
# Johnson High School      District            4761  $3,094,650.00
# Pena High School          Charter             962    $585,858.00
# Rodriguez High School    District            3999  $2,547,363.00
# Shelton High School       Charter            1761  $1,056,600.00
# Thomas High School        Charter            1635  $1,043,130.00
# ...

# %%
bins = [0, 584.99, 629.99, 644.99, 680]
group_names = ["less585", "585to630", "630to645", "645to680"]

# %%
copy_of_summary["Tesmary"] = pd.cut(copy_of_summary["Total Students"], bins, labels=group_names, include_lowest=True)
copy_of_summary
# Out:
#                       School Type  Total Students   Total Budget  \
# school_name
# Bailey High School       District            4976  $3,124,928.00
# Cabrera High School       Charter            1858  $1,081,356.00
# Figueroa High School     District            2949  $1,884,411.00
# Ford High School         District            2739  $1,763,916.00
# Griffin High School       Charter            1468    $917,500.00
# Hernandez High School    District            4635  $3,022,020.00
# Holden High School        Charter             427    $248,087.00
# Huang High School        District            2917  $1,910,635.00
# Johnson High School      District            4761  $3,094,650.00
# Pena High School          Charter             962    $585,858.00
# Rodriguez High School    District            3999  $2,547,363.00
# Shelton High School       Charter            1761  $1,056,600.00
# Thomas High School        Charter            1635  $1,043,130.00
# ...

# %%
copy_of_summary['%_Overall_Passing'] = pd.cut(copy_of_summary['% Overall Passing'], bins=bins, labels=labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3500/2349700165.py in <module>
# ----> 1 copy_of_summary['%_Overall_Passing'] = pd.cut(copy_of_summary['% Overall Passing'], bins=bins, labels=labels)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     285             raise ValueError("bins must increase monotonically.")
#     286
# --> 287     fac, bins = _bins_to_cuts(
#     288         x,
#     289         bins,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     419
#     420     side = "left" if right else "right"
# --> 421     ids = ensure_platform_int(bins.searchsorted(x, side=side))
#     422
#     423     if include_lowest:
#
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
bins2 = [0, 1000, 2000, 5000]
group_names2 = ["Small(<1000)", "Medium(1000-2000)", "Large(2000-5000)"]

# %%
copy_of_summary["TestcoreSummary"] = pd.cut(copy_of_summary["Total Students"], bins2, labels=group_names2, include_lowest=True)
copy_of_summary
# Out:
#                       School Type  Total Students   Total Budget  \
# school_name
# Bailey High School       District            4976  $3,124,928.00
# Cabrera High School       Charter            1858  $1,081,356.00
# Figueroa High School     District            2949  $1,884,411.00
# Ford High School         District            2739  $1,763,916.00
# Griffin High School       Charter            1468    $917,500.00
# Hernandez High School    District            4635  $3,022,020.00
# Holden High School        Charter             427    $248,087.00
# Huang High School        District            2917  $1,910,635.00
# Johnson High School      District            4761  $3,094,650.00
# Pena High School          Charter             962    $585,858.00
# Rodriguez High School    District            3999  $2,547,363.00
# Shelton High School       Charter            1761  $1,056,600.00
# Thomas High School        Charter            1635  $1,043,130.00
# ...
